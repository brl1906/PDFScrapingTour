# %%
import numpy as np
import pandas as pd
import tabula

# %% [markdown]
# ## working with tabula-py

# %% [markdown]
# ### <font color=green>summary</font>
# 1. the [documentation](https://pypi.org/project/tabula-py/)
# 2. Python wrapper for tabula-java, the command line interface for the table extraction engine the [Tabula](https://tabula.technology/) project. Tabula is in use for investigative reporting at news organizations :[ProPublica](https://www.propublica.org/), [Foriegn Policy](https://foreignpolicy.com/), [New York Times](https://www.nytimes.com/) and others.
# 3. It reads data and attempts to return a Pandas dataframe object by default or json optionally
# 4. docs for python wrapper don't seem as dense but helpful explanation of option parameters

# %% [markdown]
# ### <font color=red>limitations</font>

# %% [markdown]
# 1. tight text
# 2. incorrectly appending columns
# 3. chopping header data
# 4. handles rotatated sheets poorly

# %%
# nothing happening if the document is scanned
tabula_scanned_pdf = tabula.read_pdf('data/pdf_data/Final Exhibit A to Equipment Lease #29.pdf', pages=4)
type(tabula_scanned_pdf)
# Out:
# NoneType

# %%
tabula.read_pdf('data/pdf_data/camelot-twisted.pdf')
tabula.read_pdf_with_template('data/pdf_data/camelot-twisted.pdf', '')
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1                  State
# 2                    NaN
# 3                    NaN
# 4                 Kerala
# 5             Tamil Nadu
# 6              Karnataka
# 7         Andhra Pradesh
# 8            Maharashtra
# 9                Gujarat
# 10        Madhya Pradesh
# 11                Orissa
# 12           West Bengal
# 13         Uttar Pradesh
# 14                Pooled
# 15  * Data not available
# 16                  NNMB
#
#    Table 1 : STATE WISE COVERAGE PARTICULARS BY PERIOD OF SURVEY (Contd...)
# 0   Nutritional Assessment  IYCF Practices  Blood ...
# 1   (No. of individuals) (No. of mothers: 2011-12)...
# 2                                            2011-12)
# 3   1975-79 1988-90 1996-97 2011-12 Men Women Men ...
# 4         5738 6633 8864 8297 245 2161 3195 1645 2391
# 5        7387 10217 5813 7851 413 2134 2858 1119 1739
# 6        6453 8138 12606 8958 428 2467 2894 1628 2028
# 7         5844 9920 9545 8300 557 1899 2493 1111 1529
# 8         5161 7796 6883 9525 467 2368 2648 1417 1599
# 9         4403 5374 4866 9645 477 2687 3021 2122 2503
# 10                 * * * 7942 470 1965 2150 1579 1709
# 11       3756 5540 12024 8473 398 2040 2624 1093 1628
# 12                 * * * 8047 423 2058 2743 1413 2027
# 13                 * * * 9860 581 2139 2415 1185 1366
# 14  38742 53618 60601 86898 4459 21918 27041 14312...
# 15                                                NaN
# 16              72  Rural-Third Repeat Survey 2011-12

# %%
# converts automatically to dataframe by default but tight text doesn't work well
# splits colums appending incorrectly to the next column (first row)
# chops column header data
tabula.read_pdf('data/pdf_data/active_licenses.pdf')
# Out:
#     648765 AAA          ALLEGIANT AIR  \
# 0          NaN                    NaN
# 1   648766 AAA          ALLEGIANT AIR
# 2    82030 AAA      AMERICAN AIRLINES
# 3   509462 AAA      AMERICAN AIRLINES
# 4          NaN                    NaN
# 5   509609 AAA         AMERICAN EAGLE
# 6          NaN                    NaN
# 7   402986 AAA         AMERICAN EAGLE
# 8          NaN                    NaN
# 9    79145 AAA        DELTA AIR LINES
# 10  600941 AAA           ENDEAVOR AIR
# 11         NaN                    NaN
# 12  478482 AAA    EXPRESSJET AIRLINES
# 13  505981 AAA       SKYWEST AIRLINES
# 14  429754 AAA     SOUTHWEST AIRLINES
# 15         NaN    TULSA INTERNATIONAL
# 16  429755 AAA                AIRPORT
# 17  415051 AAA        UNITED AIRLINES
# 18  106719 AAA        UNITED AIRLINES
# 19         NaN       A SENSU JAPANESE
# 20  625422 BAW             RESTAURANT
# 21         NaN       ADAMO'S ROUTE 66
# 22  464828 BAW          ITALIAN VILLA
# 23         NaN                    NaN
# 24  184066 BAW                 AJANTA
# 25         NaN                    NaN
# 26  547693 BAW     AMERICINN OF SAYRE
# 27         NaN  ANDOLINI'S PIZZERIA &
# 28  428377 BAW     ITALIAN RESTAURANT
# 29         NaN         ASAHI JAPANESE
# 30  446957 BAW             RESTAURANT
# 31         NaN                    NaN
# 32  632501 BAW     BACK DOOR BARBECUE
# 33  598515 BAW     BAMBOO THAI BISTRO
# 34         NaN          BANDANA RED'S
# 35  618693 BAW             STEAKHOUSE
# 36         NaN                    NaN
# 37  632575 BAW          BASHU LEGENDS
# 38         NaN                    NaN
# 39  543149 BAW         BEDLAM BAR-B-Q
#
#                  ALLEGIANT AIR LLC7100 TERMINAL DRIVE  OKLAHOMA CITY  \
# 0                                    7777 EAST APACHE            NaN
# 1                             ALLEGIANT AIR LLCSTREET          TULSA
# 2            AMERICAN AIRLINES INC7100 TERMINAL DRIVE  OKLAHOMA CITY
# 3         AMERICAN AIRLINES INC7777 EAST APACHE DRIVE          TULSA
# 4                                      AMERICAN EAGLE            NaN
# 5                     AIRLINES INC7100 TERMINAL DRIVE  OKLAHOMA CITY
# 6                                      AMERICAN EAGLE            NaN
# 7                  AIRLINES INC7777 EAST APACHE DRIVE          TULSA
# 8                                 WILL ROGERS AIRPORT            NaN
# 9                        DELTA AIR LINES INCBOX 59975  OKLAHOMA CITY
# 10                ENDEAVOR AIR INC7100 TERMINAL DRIVE  OKLAHOMA CITY
# 11                                7100 TERMINAL DRIVE            NaN
# 12        EXPRESSJET AIRLINES INC WILL ROGERS AIRPORT  OKLAHOMA CITY
# 13                     SKYWEST INC7100 TERMINAL DRIVE  OKLAHOMA CITY
# 14         SOUTHWEST AIRLINES CO  7100 TERMINAL DRIVE  OKLAHOMA CITY
# 15                                                NaN            NaN
# 16      SOUTHWEST AIRLINES CO  7777 EAST APACHE DRIVE          TULSA
# 17          UNITED AIRLINES INC7777 EAST APACHE DRIVE          TULSA
# 18             UNITED AIRLINES INCWILL ROGERS AIRPORT  OKLAHOMA CITY
# 19                               7123 SOUTH 92ND EAST            NaN
# 20                 INFORMAL PARTNERSHIPAVENUE SUITE J          TULSA
# 21                                     2132 WEST GARY            NaN
# 22                                  TADJ INCBOULEVARD        CLINTON
# 23                                        12215 NORTH            NaN
# 24                     CABAB N' CURRY INCPENNSYLVANIA  OKLAHOMA CITY
# 25                                      SAYRE LODGING            NaN
# 26                ENTERPRISES LLC2405 SOUTH EL CAMINO          SAYRE
# 27                             12140 EAST 96TH STREET            NaN
# 28                           ANDOLINI'S LLCNORTH #106         OWASSO
# 29                                                NaN            NaN
# 30               JIN CORPORATION7831 EAST 71ST STREET          TULSA
# 31                                         SMOKEHOUSE            NaN
# 32                   ASSOCIATES INC315 NORTHWEST 23RD  OKLAHOMA CITY
# 33  BAMBOO THAI BISTRO INC  5079 SOUTH YALE AVENUE...            NaN
# 34                                                NaN            NaN
# 35           BRADSHAW, STEVE_LEN37808 OLD HIGHWAY 270        SHAWNEE
# 36                                  1522 WEST LINDSEY            NaN
# 37                            HYH HE CHUANG LLCSTREET         NORMAN
# 38                                 DEEP FORK HOLDINGS            NaN
# 39                              LLC610 NORTHEAST 50TH  OKLAHOMA CITY
#
#     Unnamed: 4   OK    73159               -  2014/12/03
# 0          NaN  NaN      NaN             NaN         NaN
# 1          NaN   OK  74115.0               -  2014/12/16
# 2          NaN   OK  73159.0  (405) 680-3701  2014/09/14
# 3          NaN   OK  74115.0  (918) 831-6302  2014/08/19
# 4          NaN  NaN      NaN             NaN         NaN
# 5          NaN   OK  73159.0  (405) 680-3701  2014/08/19
# 6          NaN  NaN      NaN             NaN         NaN
# 7          NaN   OK  74115.0  (859) 767-3747  2014/10/22
# 8          NaN  NaN      NaN             NaN         NaN
# 9          NaN   OK  73159.0  (404) 773-9745  2014/05/11
# 10         NaN   OK  73159.0  (901) 348-4100  2015/03/26
# 11         NaN  NaN      NaN             NaN         NaN
# 12         NaN   OK  73159.0  (832) 353-1201  2014/05/08
# 13         NaN   OK  73159.0  (405) 634-3000  2014/05/28
# 14         NaN   OK  73159.0  (405) 682-4183  2015/02/15
# 15         NaN  NaN      NaN             NaN         NaN
# 16         NaN   OK  74115.0  (918) 834-4495  2015/02/16
# 17         NaN   OK  74115.0  (872) 825-8309  2014/05/12
# 18         NaN   OK  73159.0  (872) 825-8309  2014/04/11
# 19         NaN  NaN      NaN             NaN         NaN
# 20         NaN   OK  74133.0  (918) 252-0333  2015/02/14
# 21         NaN  NaN      NaN             NaN         NaN
# 22         NaN   OK  73601.0  (580) 323-5900  2015/02/11
# 23         NaN  NaN      NaN             NaN         NaN
# 24         NaN   OK  73120.0  (405) 752-5283  2014/07/27
# 25         NaN  NaN      NaN             NaN         NaN
# 26         NaN   OK  73662.0  (580) 928-2700  2014/09/08
# 27         NaN  NaN      NaN             NaN         NaN
# 28         NaN   OK  74055.0  (918) 272-9325  2015/02/10
# 29         NaN  NaN      NaN             NaN         NaN
# 30         NaN   OK  74133.0  (918) 307-9151  2014/12/22
# 31         NaN  NaN      NaN             NaN         NaN
# 32         NaN   OK  73103.0               -  2014/08/01
# 33         NaN   OK  74135.0  (918) 828-0740  2015/03/11
# 34         NaN  NaN      NaN             NaN         NaN
# 35         NaN   OK  74804.0               -  2014/08/20
# 36         NaN  NaN      NaN             NaN         NaN
# 37         NaN   OK  73069.0               -  2014/07/21
# 38         NaN  NaN      NaN             NaN         NaN
# 39         NaN   OK  73105.0  (405) 528-7427  2015/02/23

# %%
tabula.read_pdf('data/pdf_data/active_licenses.pdf', guess=False)
# Out:
#            FEBRUARY 2014 M27 (BUS)  \
# 0                              NaN
# 1                              NaN
# 2                          LICENSE
# 3             NUMBER TYPE DBA NAME
# 4         648765 AAA ALLEGIANT AIR
# 5                              NaN
# 6         648766 AAA ALLEGIANT AIR
# 7      82030 AAA AMERICAN AIRLINES
# 8     509462 AAA AMERICAN AIRLINES
# 9                              NaN
# 10       509609 AAA AMERICAN EAGLE
# 11                             NaN
# 12       402986 AAA AMERICAN EAGLE
# 13                             NaN
# 14       79145 AAA DELTA AIR LINES
# 15         600941 AAA ENDEAVOR AIR
# 16                             NaN
# 17  478482 AAA EXPRESSJET AIRLINES
# 18     505981 AAA SKYWEST AIRLINES
# 19   429754 AAA SOUTHWEST AIRLINES
# 20             TULSA INTERNATIONAL
# 21              429755 AAA AIRPORT
# 22      415051 AAA UNITED AIRLINES
# 23      106719 AAA UNITED AIRLINES
# 24                A SENSU JAPANESE
# 25           625422 BAW RESTAURANT
# 26                ADAMO'S ROUTE 66
# 27        464828 BAW ITALIAN VILLA
# 28                             NaN
# 29               184066 BAW AJANTA
# 30                             NaN
# 31   547693 BAW AMERICINN OF SAYRE
# 32           ANDOLINI'S PIZZERIA &
# 33   428377 BAW ITALIAN RESTAURANT
# 34                  ASAHI JAPANESE
# 35           446957 BAW RESTAURANT
# 36                             NaN
# 37   632501 BAW BACK DOOR BARBECUE
# 38   598515 BAW BAMBOO THAI BISTRO
# 39                   BANDANA RED'S
# 40           618693 BAW STEAKHOUSE
# 41                             NaN
# 42        632575 BAW BASHU LEGENDS
# 43                             NaN
# 44       543149 BAW BEDLAM BAR-B-Q
# 45                             NaN
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                       LICENSEE NAME
# 4                                   ALLEGIANT AIR LLC
# 5                                                 NaN
# 6                                   ALLEGIANT AIR LLC
# 7                               AMERICAN AIRLINES INC
# 8                               AMERICAN AIRLINES INC
# 9                                      AMERICAN EAGLE
# 10                                       AIRLINES INC
# 11                                     AMERICAN EAGLE
# 12                                       AIRLINES INC
# 13                                                NaN
# 14                                DELTA AIR LINES INC
# 15                                   ENDEAVOR AIR INC
# 16                                                NaN
# 17        EXPRESSJET AIRLINES INC WILL ROGERS AIRPORT
# 18                                        SKYWEST INC
# 19         SOUTHWEST AIRLINES CO  7100 TERMINAL DRIVE
# 20                                                NaN
# 21      SOUTHWEST AIRLINES CO  7777 EAST APACHE DRIVE
# 22                                UNITED AIRLINES INC
# 23                                UNITED AIRLINES INC
# 24                                                NaN
# 25                               INFORMAL PARTNERSHIP
# 26                                                NaN
# 27                                           TADJ INC
# 28                                                NaN
# 29                                 CABAB N' CURRY INC
# 30                                      SAYRE LODGING
# 31                                    ENTERPRISES LLC
# 32                                                NaN
# 33                                     ANDOLINI'S LLC
# 34                                                NaN
# 35                                    JIN CORPORATION
# 36                                         SMOKEHOUSE
# 37                                     ASSOCIATES INC
# 38  BAMBOO THAI BISTRO INC  5079 SOUTH YALE AVENUE...
# 39                                                NaN
# 40                                BRADSHAW, STEVE_LEN
# 41                                                NaN
# 42                                  HYH HE CHUANG LLC
# 43                                 DEEP FORK HOLDINGS
# 44                                                LLC
# 45                                                NaN
#
#           ALPHABETIC LISTING BY TYPE Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 0                 OF ACTIVE LICENSES        NaN        NaN             NaN
# 1           OKLAHOMA ABLE COMMISSION        NaN        NaN             NaN
# 2                            PREMISE        NaN        NaN             NaN
# 3                       ADDRESS CITY         ST        ZIP    PHONE NUMBER
# 4   7100 TERMINAL DRIVEOKLAHOMA CITY         OK      73159               -
# 5                   7777 EAST APACHE        NaN        NaN             NaN
# 6                        STREETTULSA         OK      74115               -
# 7   7100 TERMINAL DRIVEOKLAHOMA CITY         OK      73159  (405) 680-3701
# 8        7777 EAST APACHE DRIVETULSA         OK      74115  (918) 831-6302
# 9                                NaN        NaN        NaN             NaN
# 10  7100 TERMINAL DRIVEOKLAHOMA CITY         OK      73159  (405) 680-3701
# 11                               NaN        NaN        NaN             NaN
# 12       7777 EAST APACHE DRIVETULSA         OK      74115  (859) 767-3747
# 13               WILL ROGERS AIRPORT        NaN        NaN             NaN
# 14            BOX 59975OKLAHOMA CITY         OK      73159  (404) 773-9745
# 15  7100 TERMINAL DRIVEOKLAHOMA CITY         OK      73159  (901) 348-4100
# 16               7100 TERMINAL DRIVE        NaN        NaN             NaN
# 17                     OKLAHOMA CITY         OK      73159  (832) 353-1201
# 18  7100 TERMINAL DRIVEOKLAHOMA CITY         OK      73159  (405) 634-3000
# 19                     OKLAHOMA CITY         OK      73159  (405) 682-4183
# 20                               NaN        NaN        NaN             NaN
# 21                             TULSA         OK      74115  (918) 834-4495
# 22       7777 EAST APACHE DRIVETULSA         OK      74115  (872) 825-8309
# 23  WILL ROGERS AIRPORTOKLAHOMA CITY         OK      73159  (872) 825-8309
# 24              7123 SOUTH 92ND EAST        NaN        NaN             NaN
# 25               AVENUE SUITE JTULSA         OK      74133  (918) 252-0333
# 26                    2132 WEST GARY        NaN        NaN             NaN
# 27                  BOULEVARDCLINTON         OK      73601  (580) 323-5900
# 28                       12215 NORTH        NaN        NaN             NaN
# 29         PENNSYLVANIAOKLAHOMA CITY         OK      73120  (405) 752-5283
# 30                               NaN        NaN        NaN             NaN
# 31         2405 SOUTH EL CAMINOSAYRE         OK      73662  (580) 928-2700
# 32            12140 EAST 96TH STREET        NaN        NaN             NaN
# 33                  NORTH #106OWASSO         OK      74055  (918) 272-9325
# 34                               NaN        NaN        NaN             NaN
# 35        7831 EAST 71ST STREETTULSA         OK      74133  (918) 307-9151
# 36                               NaN        NaN        NaN             NaN
# 37   315 NORTHWEST 23RDOKLAHOMA CITY         OK      73103               -
# 38                               NaN         OK      74135  (918) 828-0740
# 39                               NaN        NaN        NaN             NaN
# 40      37808 OLD HIGHWAY 270SHAWNEE         OK      74804               -
# 41                 1522 WEST LINDSEY        NaN        NaN             NaN
# 42                      STREETNORMAN         OK      73069               -
# 43                               NaN        NaN        NaN             NaN
# 44   610 NORTHEAST 50THOKLAHOMA CITY         OK      73105  (405) 528-7427
# 45                     Page 1 of 151        NaN        NaN             NaN
#
#       ABLPDM27
# 0    3/19/2014
# 1          NaN
# 2          NaN
# 3      EXPIRES
# 4   2014/12/03
# 5          NaN
# 6   2014/12/16
# 7   2014/09/14
# 8   2014/08/19
# 9          NaN
# 10  2014/08/19
# 11         NaN
# 12  2014/10/22
# 13         NaN
# 14  2014/05/11
# 15  2015/03/26
# 16         NaN
# 17  2014/05/08
# 18  2014/05/28
# 19  2015/02/15
# 20         NaN
# 21  2015/02/16
# 22  2014/05/12
# 23  2014/04/11
# 24         NaN
# 25  2015/02/14
# 26         NaN
# 27  2015/02/11
# 28         NaN
# 29  2014/07/27
# 30         NaN
# 31  2014/09/08
# 32         NaN
# 33  2015/02/10
# 34         NaN
# 35  2014/12/22
# 36         NaN
# 37  2014/08/01
# 38  2015/03/11
# 39         NaN
# 40  2014/08/20
# 41         NaN
# 42  2014/07/21
# 43         NaN
# 44  2015/02/23
# 45         NaN

# %% [markdown]
# ### <font color=orange>useful</font>
# 1. auto detect structure break in table to retun only table elements: no title no paragraph
# 2. conversion to dataframe in <font color=green><b>8</b></font> lines
# 3. converstion to excel or csv in <font color=green><b>9</b></font> lines
# 4. has useful ```pages``` parameter for setting target page number to read into the function that attempts to parse and return df or json. takes list or 'all'

# %% [markdown]
# ## performs well if the document is searchable & you know, in advance, the target page with table

# %%
df = tabula.read_pdf('data/pdf_data/exhibita-10-15-2018.pdf', pages=4)
cols = []
[cols.append('{} {}'.format(k.split('.')[0],v))for k,v in zip(df.iloc[0].index, df.iloc[0])]
df.drop([0,1,2,23,24],inplace=True)
df.columns = cols
for col in df.columns[2:]:
    df[col] = df[col].apply(lambda x: float(x.replace(',','')))
df.set_index('Payment No.', inplace=True)

# %%
df
# Out:
#             Payment Date  Payment Amount  Interest Component  \
# Payment No.
# 1               5/1/2018      1100264.54           273262.18
# 2              11/1/2018      1100264.54           271872.65
# 3               5/1/2019      1100264.54           259405.35
# 4              11/1/2019      1100264.54           246750.42
# 5               5/1/2020      1100264.54           233905.03
# 6              11/1/2020      1100264.54           220866.32
# 7               5/1/2021      1100264.54           207631.38
# 8              11/1/2021      1100264.54           194197.25
# 9               5/1/2022      1100264.54           180560.93
# 10             11/1/2022      1100264.54           166719.39
# 11              5/1/2023      1100264.54           152669.54
# 12             11/1/2023      1100264.54           138408.24
# 13              5/1/2024      1100264.54           123932.30
# 14             11/1/2024      1100264.54           109238.50
# 15              5/1/2025      1100264.54            94323.56
# 16             11/1/2025      1100264.54            79184.14
# 17              5/1/2026      1100264.54            63816.88
# 18             11/1/2026      1100264.54            48218.35
# 19              5/1/2027      1100264.54            32385.05
# 20             11/1/2027      1100264.54            16313.34
#
#              Principal Component  Purchase Price
# Payment No.
# 1                      827002.36     18606566.47
# 2                      828391.89     17753322.82
# 3                      840859.19     16887237.86
# 4                      853514.12     16008118.31
# 5                      866359.51     15115768.02
# 6                      879398.22     14209987.85
# 7                      892633.16     13290575.70
# 8                      906067.29     12357326.39
# 9                      919703.61     11410031.67
# 10                     933545.15     10448480.17
# 11                     947595.00      9472457.32
# 12                     961856.30      8481745.33
# 13                     976332.24      7476123.12
# 14                     991026.04      6455366.30
# 15                    1005940.98      5419247.09
# 16                    1021080.40      4367534.28
# 17                    1036447.66      3299993.19
# 18                    1052046.19      2216385.61
# 19                    1067879.49      1116469.74
# 20                    1083951.20            0.00

# %%
df.to_excel('tabula-to-excel.xlsx')

# %%
# handles multiple pages, merging into one object to render dataframe
# unlike camelot-py which parses a document to return tables and pages individually
import camelot
camelot_page_limitation = camelot.read_pdf('data/pdf_data/active_licenses.pdf', flavor='stream')
camelot_page_limitation
# Out:
# UserWarning: No tables found on page-1 [stream.py:292]
# <TableList n=1>

# %%
print('pages returned with camelot: {}'.format(camelot_page_limitation.n))
camelot_page_limitation[0].df.tail(5)
# Out:
# pages returned with camelot: 1
#    0                                                  1                   2  \
# 42
# 43    632575 BAW BASHU LEGENDS                 HYH H...
# 44                                                       DEEP FORK HOLDINGS
# 45                            543149 BAW BEDLAM BAR-B-Q                 LLC
# 46
#
#                                             3   4      5               6  \
# 42                          1522 WEST LINDSEY
# 43               STREET                NORMAN  OK  73069               -
# 44
# 45  610 NORTHEAST 50TH          OKLAHOMA CITY  OK  73105  (405) 528-7427
# 46                              Page 1 of 151
#
#              7
# 42
# 43  2014/07/21
# 44
# 45  2015/02/23
# 46

# %%
tabula_license_page1 = tabula.read_pdf('data/pdf_data/active_licenses.pdf',pages=1)

# %%
tabula_license_page2 = tabula.read_pdf('data/pdf_data/active_licenses.pdf',pages=2)

# %%
tabula.read_pdf('data/pdf_data/active_licenses.pdf',pages=[1,2])
# Out:
#     648765 AAA                               ALLEGIANT AIR  \
# 0          NaN                                         NaN
# 1   648766 AAA                               ALLEGIANT AIR
# 2    82030 AAA                           AMERICAN AIRLINES
# 3   509462 AAA                           AMERICAN AIRLINES
# 4          NaN                                         NaN
# 5   509609 AAA                              AMERICAN EAGLE
# 6          NaN                                         NaN
# 7   402986 AAA                              AMERICAN EAGLE
# 8          NaN                                         NaN
# 9    79145 AAA                             DELTA AIR LINES
# 10  600941 AAA                                ENDEAVOR AIR
# 11         NaN                                         NaN
# 12  478482 AAA                         EXPRESSJET AIRLINES
# 13  505981 AAA                            SKYWEST AIRLINES
# 14  429754 AAA                          SOUTHWEST AIRLINES
# 15         NaN                         TULSA INTERNATIONAL
# 16  429755 AAA                                     AIRPORT
# 17  415051 AAA                             UNITED AIRLINES
# 18  106719 AAA                             UNITED AIRLINES
# 19         NaN                            A SENSU JAPANESE
# 20  625422 BAW                                  RESTAURANT
# 21         NaN                            ADAMO'S ROUTE 66
# 22  464828 BAW                               ITALIAN VILLA
# 23         NaN                                         NaN
# 24  184066 BAW                                      AJANTA
# 25         NaN                                         NaN
# 26  547693 BAW                          AMERICINN OF SAYRE
# 27         NaN                       ANDOLINI'S PIZZERIA &
# 28  428377 BAW                          ITALIAN RESTAURANT
# 29         NaN                              ASAHI JAPANESE
# ..         ...                                         ...
# 53  487016 BAW    CLASSIC CIGAR LOUNGEINFORMAL PARTNERSHIP
# 54         NaN                                         NaN
# 55  617276 BAW                    COFFEE CUPCOFFEE CUP LLC
# 56         NaN                         COOLGREENS BEER AND
# 57  603771 BAW                          COOLGREENSWINE LLC
# 58         NaN                         COOLGREENS BEER AND
# 59  603772 BAW                          COOLGREENSWINE LLC
# 60         NaN                         COOLGREENS BEER AND
# 61  603773 BAW                          COOLGREENSWINE LLC
# 62         NaN                         COOLGREENS BEER AND
# 63  603770 BAW                          COOLGREENSWINE LLC
# 64         NaN                                         NaN
# 65  643433 BAW                      COW CREEK CAFEOEME LLC
# 66         NaN    DAVINCI'S ITALIAN NAPOLI'S OF STILLWATER
# 67  561218 BAW                               RESTAURANTINC
# 68  635527 BAW  DIARTI ITALIAN CAFEDIARTI ITALIAN CAFE LLC
# 69         NaN                             DOMENICA ITALIA
# 70  623823 BAW                     KITCHENMARINI, DOMENICA
# 71         NaN                        ELEMENTS ART GALLERY
# 72  633246 BAW                   ELEMENTS ART GALLERY  LLC
# 73         NaN                            FAT GUY'S BURGER
# 74  549471 BAW                             JOINTALSOKC LLC
# 75         NaN                            FAT GUY'S BURGER
# 76  614377 BAW                             JOINTALSOKC LLC
# 77         NaN                             FONTANA ITALIAN
# 78  632300 BAW                       RESTAURANTULAJ, GEZIM
# 79         NaN                                         NaN
# 80  507875 BAW                       FRATELI'SFRATLI'S INC
# 81         NaN                                         NaN
# 82  604941 BAW                FRESCOS MEXICAN GRILL 19 INC
#
#              ALLEGIANT AIR LLC7100 TERMINAL DRIVE  OKLAHOMA CITY  Unnamed: 4  \
# 0                                7777 EAST APACHE            NaN         NaN
# 1                         ALLEGIANT AIR LLCSTREET          TULSA         NaN
# 2        AMERICAN AIRLINES INC7100 TERMINAL DRIVE  OKLAHOMA CITY         NaN
# 3     AMERICAN AIRLINES INC7777 EAST APACHE DRIVE          TULSA         NaN
# 4                                  AMERICAN EAGLE            NaN         NaN
# 5                 AIRLINES INC7100 TERMINAL DRIVE  OKLAHOMA CITY         NaN
# 6                                  AMERICAN EAGLE            NaN         NaN
# 7              AIRLINES INC7777 EAST APACHE DRIVE          TULSA         NaN
# 8                             WILL ROGERS AIRPORT            NaN         NaN
# 9                    DELTA AIR LINES INCBOX 59975  OKLAHOMA CITY         NaN
# 10            ENDEAVOR AIR INC7100 TERMINAL DRIVE  OKLAHOMA CITY         NaN
# 11                            7100 TERMINAL DRIVE            NaN         NaN
# 12    EXPRESSJET AIRLINES INC WILL ROGERS AIRPORT  OKLAHOMA CITY         NaN
# 13                 SKYWEST INC7100 TERMINAL DRIVE  OKLAHOMA CITY         NaN
# 14     SOUTHWEST AIRLINES CO  7100 TERMINAL DRIVE  OKLAHOMA CITY         NaN
# 15                                            NaN            NaN         NaN
# 16  SOUTHWEST AIRLINES CO  7777 EAST APACHE DRIVE          TULSA         NaN
# 17      UNITED AIRLINES INC7777 EAST APACHE DRIVE          TULSA         NaN
# 18         UNITED AIRLINES INCWILL ROGERS AIRPORT  OKLAHOMA CITY         NaN
# 19                           7123 SOUTH 92ND EAST            NaN         NaN
# 20             INFORMAL PARTNERSHIPAVENUE SUITE J          TULSA         NaN
# 21                                 2132 WEST GARY            NaN         NaN
# 22                              TADJ INCBOULEVARD        CLINTON         NaN
# 23                                    12215 NORTH            NaN         NaN
# 24                 CABAB N' CURRY INCPENNSYLVANIA  OKLAHOMA CITY         NaN
# 25                                  SAYRE LODGING            NaN         NaN
# 26            ENTERPRISES LLC2405 SOUTH EL CAMINO          SAYRE         NaN
# 27                         12140 EAST 96TH STREET            NaN         NaN
# 28                       ANDOLINI'S LLCNORTH #106         OWASSO         NaN
# 29                                            NaN            NaN         NaN
# ..                                            ...            ...         ...
# 53                                  EXPRESSWAY #O         OWASSO         NaN
# 54                             401 NORTH BROADWAY            NaN         NaN
# 55                                         STREET         POTEAU         NaN
# 56                                            NaN            NaN         NaN
# 57           14201 NORTH MAY AVENUE OKLAHOMA CITY            NaN         NaN
# 58                                            NaN            NaN         NaN
# 59               1189 EAST 15TH SUITE 156  EDMOND            NaN         NaN
# 60                             204 NORTH ROBINSON            NaN         NaN
# 61                                      SUITE 150  OKLAHOMA CITY         NaN
# 62                                            NaN            NaN         NaN
# 63                             3700 WEST ROBINSON         NORMAN         NaN
# 64                           387 SOUTH COMMERCIAL            NaN         NaN
# 65                                         STREET          WELCH         NaN
# 66                             2280 NORTH PERKINS            NaN         NaN
# 67                                           ROAD     STILLWATER         NaN
# 68                                2808 8TH STREET       WOODWARD         NaN
# 69                            2033 NORTH KICKAPOO            NaN         NaN
# 70                                         AVENUE        SHAWNEE         NaN
# 71                                            NaN            NaN         NaN
# 72                           125 WEST MAIN STREET         DURANT         NaN
# 73                            140 NORTH GREENWOOD            NaN         NaN
# 74                                         AVENUE          TULSA         NaN
# 75                            7945 SOUTH MEMORIAL            NaN         NaN
# 76                                          DRIVE          TULSA         NaN
# 77                             854 NORTHWEST 12TH            NaN         NaN
# 78                                         STREET          MOORE         NaN
# 79                            1945 NORTH KICKAPOO            NaN         NaN
# 80                                         AVENUE        SHAWNEE         NaN
# 81                             1010 LONNIE ABBOTT            NaN         NaN
# 82                                      BOULEVARD            ADA         NaN
#
#      OK    73159               -  2014/12/03
# 0   NaN      NaN             NaN         NaN
# 1    OK  74115.0               -  2014/12/16
# 2    OK  73159.0  (405) 680-3701  2014/09/14
# 3    OK  74115.0  (918) 831-6302  2014/08/19
# 4   NaN      NaN             NaN         NaN
# 5    OK  73159.0  (405) 680-3701  2014/08/19
# 6   NaN      NaN             NaN         NaN
# 7    OK  74115.0  (859) 767-3747  2014/10/22
# 8   NaN      NaN             NaN         NaN
# 9    OK  73159.0  (404) 773-9745  2014/05/11
# 10   OK  73159.0  (901) 348-4100  2015/03/26
# 11  NaN      NaN             NaN         NaN
# 12   OK  73159.0  (832) 353-1201  2014/05/08
# 13   OK  73159.0  (405) 634-3000  2014/05/28
# 14   OK  73159.0  (405) 682-4183  2015/02/15
# 15  NaN      NaN             NaN         NaN
# 16   OK  74115.0  (918) 834-4495  2015/02/16
# 17   OK  74115.0  (872) 825-8309  2014/05/12
# 18   OK  73159.0  (872) 825-8309  2014/04/11
# 19  NaN      NaN             NaN         NaN
# 20   OK  74133.0  (918) 252-0333  2015/02/14
# 21  NaN      NaN             NaN         NaN
# 22   OK  73601.0  (580) 323-5900  2015/02/11
# 23  NaN      NaN             NaN         NaN
# 24   OK  73120.0  (405) 752-5283  2014/07/27
# 25  NaN      NaN             NaN         NaN
# 26   OK  73662.0  (580) 928-2700  2014/09/08
# 27  NaN      NaN             NaN         NaN
# 28   OK  74055.0  (918) 272-9325  2015/02/10
# 29  NaN      NaN             NaN         NaN
# ..  ...      ...             ...         ...
# 53   OK  74055.0  (918) 274-8191  2015/02/10
# 54  NaN      NaN             NaN         NaN
# 55   OK  74953.0  (918) 647-2622  2014/10/25
# 56  NaN      NaN             NaN         NaN
# 57   OK  73134.0  (405) 286-9304  2014/07/02
# 58  NaN      NaN             NaN         NaN
# 59   OK  73013.0  (405) 562-1022  2014/07/02
# 60  NaN      NaN             NaN         NaN
# 61   OK  73102.0  (405) 600-6444  2014/06/25
# 62  NaN      NaN             NaN         NaN
# 63   OK  73072.0  (405) 701-5000  2014/06/18
# 64  NaN      NaN             NaN         NaN
# 65   OK  74369.0  (918) 788-3683  2015/02/23
# 66  NaN      NaN             NaN         NaN
# 67   OK  74075.0  (405) 372-0300  2014/10/20
# 68   OK  73801.0               -  2014/07/18
# 69  NaN      NaN             NaN         NaN
# 70   OK  74804.0               -  2014/06/10
# 71  NaN      NaN             NaN         NaN
# 72   OK  74701.0               -  2014/06/05
# 73  NaN      NaN             NaN         NaN
# 74   OK  74120.0  (918) 794-7782  2015/04/01
# 75  NaN      NaN             NaN         NaN
# 76   OK  74133.0  (918) 893-2232  2014/09/19
# 77  NaN      NaN             NaN         NaN
# 78   OK  73160.0  (405) 703-0911  2014/05/07
# 79  NaN      NaN             NaN         NaN
# 80   OK  74804.0  (405) 275-6103  2014/08/28
# 81  NaN      NaN             NaN         NaN
# 82   OK  74820.0  (580) 332-2959  2014/07/15
#
# [83 rows x 9 columns]
