# %%
from pdf2image import convert_from_path, convert_from_bytes

# %% [markdown]
# ## working with pdf2image

# %%
scanned_pdf_images = convert_from_path('data/pdf_data/Final Exhibit A to Equipment Lease #29.pdf')

# %%
# check the number of pages in document returned as image
len(scanned_pdf_images)
# Out:
# 72

# %%
# target an individual page
scanned_pdf_images[3]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x103A777F0>
